# %%
! python --version
# Out:
# Python 3.12.8

# %%
pip install pandas matplotlib seaborn plotly scikit-learn streamlit jupyter texthero openai
# Out:
# ...
#   Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached streamlit-1.47.1-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached texthero-1.1.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached openai-1.98.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Projects\\english-premier-league-capstone-project\\english-premier-league-capstone-project\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Projects\\english-premier-league-capstone-project\\english-premier-league-capstone-project'

# %%
import os
import pandas as pd

# %%
# Set working directory to the root of your project
os.chdir("c:\\Projects\\english-premier-league-capstone-project\\english-premier-league-capstone-project")

# %%
# Now load the file relative to this
df = pd.read_csv("data/epl_final.csv")

# %% [markdown]
# # Load and Preview the Data set
# This cell loads the `epl_final.csv` file using pandas and displays the first 5 rows to get an initial look at the data

# %%
# Now load the file relative to this
df = pd.read_csv("data/epl_final.csv")

# %%
# Show the first 5 rows
df.head()
# Out:
#     Season   MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01  2000-08-19  Charlton       Man City                  4
# 1  2000/01  2000-08-19   Chelsea       West Ham                  4
# 2  2000/01  2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01  2000-08-19     Derby    Southampton                  2
# 4  2000/01  2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  HomeShotsOnTarget  AwayShotsOnTarget  HomeCorners  \
# ...

# %% [markdown]
# # Preview the Data set
# Now this is going to check the first 1000 rows and 22 Columns to get a good look of the bulk of the data

# %%
# Display the first 1000 rows of the DataFrame
df.head(1000)
# Out:
#       Season   MatchDate   HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0    2000/01  2000-08-19   Charlton       Man City                  4
# 1    2000/01  2000-08-19    Chelsea       West Ham                  4
# 2    2000/01  2000-08-19   Coventry  Middlesbrough                  1
# 3    2000/01  2000-08-19      Derby    Southampton                  2
# 4    2000/01  2000-08-19      Leeds        Everton                  2
# ..       ...         ...        ...            ...                ...
# 995  2002/03  2003-01-19    Arsenal       West Ham                  3
# 996  2002/03  2003-01-19     Fulham  Middlesbrough                  1
# 997  2002/03  2003-01-22   Charlton       West Ham                  4
# 998  2002/03  2003-01-22  Newcastle         Bolton                  1
# 999  2002/03  2003-01-28     Bolton        Everton                  1
#
#      FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Dataset Structure
# This will now check the structure of the Dataset

# %%
# Get dataset structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9380 entries, 0 to 9379
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Season             9380 non-null   object
#  1   MatchDate          9380 non-null   object
#  2   HomeTeam           9380 non-null   object
#  3   AwayTeam           9380 non-null   object
#  4   FullTimeHomeGoals  9380 non-null   int64
#  5   FullTimeAwayGoals  9380 non-null   int64
#  6   FullTimeResult     9380 non-null   object
#  7   HalfTimeHomeGoals  9380 non-null   int64
#  8   HalfTimeAwayGoals  9380 non-null   int64
#  9   HalfTimeResult     9380 non-null   object
#  10  HomeShots          9380 non-null   int64
#  11  AwayShots          9380 non-null   int64
#  12  HomeShotsOnTarget  9380 non-null   int64
#  13  AwayShotsOnTarget  9380 non-null   int64
#  14  HomeCorners        9380 non-null   int64
#  15  AwayCorners        9380 non-null   int64
# ...

# %% [markdown]
# # Explanation:
# You’ll see column names, data types, and missing values (if any missing).

# %% [markdown]
# ---

# %% [markdown]
# # Statistic Checks:
# This is to check for numerical columns

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#        FullTimeHomeGoals  FullTimeAwayGoals  HalfTimeHomeGoals  \
# count        9380.000000        9380.000000        9380.000000
# mean            1.535394           1.182623           0.688273
# std             1.305432           1.157414           0.835079
# min             0.000000           0.000000           0.000000
# 25%             1.000000           0.000000           0.000000
# 50%             1.000000           1.000000           0.000000
# 75%             2.000000           2.000000           1.000000
# max             9.000000           9.000000           5.000000
#
#        HalfTimeAwayGoals    HomeShots    AwayShots  HomeShotsOnTarget  \
# count        9380.000000  9380.000000  9380.000000        9380.000000
# mean            0.518763    13.617484    10.810661           5.973134
# std             0.735357     5.356424     4.696501           3.267954
# min             0.000000     0.000000     0.000000           0.000000
# ...

# %% [markdown]
# # Explanation:
# This shows: count, mean, median, standard deviation, min, max, etc.

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains information about teams in the English Premier League (EPL).
# Columns include performance statistics such as:
# - Goals
# - Home Shots
# - Away Shots
# - Corners
# - Yellow Cards/Red Cards
#
# We start by checking for missing values and data types.

# %% [markdown]
# # Check for Missing Values

# %%
# Count missing values
df.isnull().sum()
# Out:
# Season               0
# MatchDate            0
# HomeTeam             0
# AwayTeam             0
# FullTimeHomeGoals    0
# FullTimeAwayGoals    0
# FullTimeResult       0
# HalfTimeHomeGoals    0
# HalfTimeAwayGoals    0
# HalfTimeResult       0
# HomeShots            0
# AwayShots            0
# HomeShotsOnTarget    0
# AwayShotsOnTarget    0
# HomeCorners          0
# AwayCorners          0
# HomeFouls            0
# AwayFouls            0
# HomeYellowCards      0
# AwayYellowCards      0
# HomeRedCards         0
# AwayRedCards         0
# dtype: int64

# %% [markdown]
# # Explanation:
# No missing values in the data

# %% [markdown]
# ## Data Cleaning and Descriptive Statistics
#
# * First, check again for missing values
# * Data Cleaning & Preparation (Match Results Focus)

# %%
# Check how many missing values each column has
df.isnull().sum().sort_values(ascending=False)
# Out:
# Season               0
# MatchDate            0
# HomeTeam             0
# AwayTeam             0
# FullTimeHomeGoals    0
# FullTimeAwayGoals    0
# FullTimeResult       0
# HalfTimeHomeGoals    0
# HalfTimeAwayGoals    0
# HalfTimeResult       0
# HomeShots            0
# AwayShots            0
# HomeShotsOnTarget    0
# AwayShotsOnTarget    0
# HomeCorners          0
# AwayCorners          0
# HomeFouls            0
# AwayFouls            0
# HomeYellowCards      0
# AwayYellowCards      0
# HomeRedCards         0
# AwayRedCards         0
# dtype: int64

# %% [markdown]
# As checked again there is no missing data

# %% [markdown]
# # Check the actual column names

# %%
# Check the actual column names in the dataset
print("Column names in the dataset:")
print(df.columns.tolist())
# Out:
# Column names in the dataset:
# ['Season', 'MatchDate', 'HomeTeam', 'AwayTeam', 'FullTimeHomeGoals', 'FullTimeAwayGoals', 'FullTimeResult', 'HalfTimeHomeGoals', 'HalfTimeAwayGoals', 'HalfTimeResult', 'HomeShots', 'AwayShots', 'HomeShotsOnTarget', 'AwayShotsOnTarget', 'HomeCorners', 'AwayCorners', 'HomeFouls', 'AwayFouls', 'HomeYellowCards', 'AwayYellowCards', 'HomeRedCards', 'AwayRedCards']

# %%
# Check for columns that might contain goals/assists data
goals_cols = [col for col in df.columns if 'goal' in col.lower()]
assists_cols = [col for col in df.columns if 'assist' in col.lower()]

print("Columns containing 'goal':", goals_cols)
print("Columns containing 'assist':", assists_cols)
# Out:
# Columns containing 'goal': ['FullTimeHomeGoals', 'FullTimeAwayGoals', 'HalfTimeHomeGoals', 'HalfTimeAwayGoals']
# Columns containing 'assist': []

# %%
# Let's also see what other columns we have to work with
print("All columns in the dataset:")
for i, col in enumerate(df.columns, 1):
    print(f"{i:2d}. {col}")
# Out:
# All columns in the dataset:
#  1. Season
#  2. MatchDate
#  3. HomeTeam
#  4. AwayTeam
#  5. FullTimeHomeGoals
#  6. FullTimeAwayGoals
#  7. FullTimeResult
#  8. HalfTimeHomeGoals
#  9. HalfTimeAwayGoals
# 10. HalfTimeResult
# 11. HomeShots
# 12. AwayShots
# 13. HomeShotsOnTarget
# 14. AwayShotsOnTarget
# 15. HomeCorners
# 16. AwayCorners
# 17. HomeFouls
# 18. AwayFouls
# 19. HomeYellowCards
# 20. AwayYellowCards
# 21. HomeRedCards
# 22. AwayRedCards

# %%
# Since this is match data with goals but no assists, let's clean based on the goal columns
df_clean = df.dropna(subset=['FullTimeHomeGoals', 'FullTimeAwayGoals'])

# %%
# Check the shape before and after cleaning
print(f"Original dataset shape: {df.shape}")
print(f"Cleaned dataset shape: {df_clean.shape}")
# Out:
# Original dataset shape: (9380, 22)
# Cleaned dataset shape: (9380, 22)

# %%
# Example: Fill missing numerical columns with 0
df = df.fillna(0)

# %%
# Drop rows with any missing values
df = df.dropna()

# %% [markdown]
# #  3.2 Convert 'Date' Column to DateTime
# Now this will be making sure the Date column (if present) is in datetime format:

# %%
# Convert the existing 'MatchDate' column to datetime and sort by it
df['MatchDate'] = pd.to_datetime(df['MatchDate'])
df.sort_values('MatchDate', inplace=True)

# %% [markdown]
#  Create Match Outcome and Goal Features

# %%
# Match outcome for home team
def get_result(row):
    if row['FullTimeHomeGoals'] > row['FullTimeAwayGoals']:
        return 'Home Win'
    elif row['FullTimeHomeGoals'] < row['FullTimeAwayGoals']:
        return 'Away Win'
    else:
        return 'Draw'

df['Result'] = df.apply(get_result, axis=1)

# Goal difference
df['Goal_Diff'] = df['FullTimeHomeGoals'] - df['FullTimeAwayGoals']

# Total goals
df['Total_Goals'] = df['FullTimeHomeGoals'] + df['FullTimeAwayGoals']

# %% [markdown]
# Adding the columns of 'Home Win', 'Away Win' and 'Draw' to help with the analysis

# %% [markdown]
# # Descriptive Statistics & Visualisation
# Match Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Preview data
df.head()
# Out:
#     Season  MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01 2000-08-19  Charlton       Man City                  4
# 1  2000/01 2000-08-19   Chelsea       West Ham                  4
# 2  2000/01 2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01 2000-08-19     Derby    Southampton                  2
# 4  2000/01 2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  AwayCorners  HomeFouls  AwayFouls  HomeYellowCards  \
# ...

# %%
# Preview data
df.head(1000)
# Out:
#       Season  MatchDate   HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0    2000/01 2000-08-19   Charlton       Man City                  4
# 1    2000/01 2000-08-19    Chelsea       West Ham                  4
# 2    2000/01 2000-08-19   Coventry  Middlesbrough                  1
# 3    2000/01 2000-08-19      Derby    Southampton                  2
# 4    2000/01 2000-08-19      Leeds        Everton                  2
# ..       ...        ...        ...            ...                ...
# 995  2002/03 2003-01-19    Arsenal       West Ham                  3
# 996  2002/03 2003-01-19     Fulham  Middlesbrough                  1
# 997  2002/03 2003-01-22   Charlton       West Ham                  4
# 998  2002/03 2003-01-22  Newcastle         Bolton                  1
# 999  2002/03 2003-01-28     Bolton        Everton                  1
#
#      FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Season', 'MatchDate', 'HomeTeam', 'AwayTeam', 'FullTimeHomeGoals',
#        'FullTimeAwayGoals', 'FullTimeResult', 'HalfTimeHomeGoals',
#        'HalfTimeAwayGoals', 'HalfTimeResult', 'HomeShots', 'AwayShots',
#        'HomeShotsOnTarget', 'AwayShotsOnTarget', 'HomeCorners', 'AwayCorners',
#        'HomeFouls', 'AwayFouls', 'HomeYellowCards', 'AwayYellowCards',
#        'HomeRedCards', 'AwayRedCards', 'Result', 'Goal_Diff', 'Total_Goals'],
#       dtype='object')

# %% [markdown]
# ## Match Outcomes

# %%
# Count of each match result
sns.countplot(x='Result', data=df)
plt.title('Match Result Distribution')
plt.xlabel('Result')
plt.ylabel('Number of Matches')
plt.show()

# %% [markdown]
# This chart shows the number of Home Wins, Away Wins, and Draws in the season.

# %% [markdown]
# ---

# %% [markdown]
# Home vs Away Performance
# - Average goals scored:

# %%
home_avg = df['FullTimeHomeGoals'].mean()
away_avg = df['FullTimeAwayGoals'].mean()

print(f'Average Home Goals: {home_avg:.2f}')
print(f'Average Away Goals: {away_avg:.2f}')
# Out:
# Average Home Goals: 1.54
# Average Away Goals: 1.18

# %% [markdown]
# ---

# %% [markdown]
# ## Home vs Away Goal Comparison

# %%
sns.barplot(x=['Home Goals', 'Away Goals'], y=[home_avg, away_avg])
plt.title('Average Goals Scored: Home vs Away')
plt.ylabel('Goals')
plt.show()

# %% [markdown]
# This visual compares the average number of goals scored by home teams and away teams

# %% [markdown]
# ---

# %% [markdown]
# # Goal Scoring Patterns

# %%
sns.histplot(df['Total_Goals'], bins=15, kde=True)
plt.title('Distribution of Total Goals per Match')
plt.xlabel('Total Goals')
plt.ylabel('Number of Matches')
plt.show()

# %% [markdown]
#     - Histogram of Total Goals

# %% [markdown]
# ---

# %% [markdown]
# # Team Performance Over Time

# %%
df['MatchDate'] = pd.to_datetime(df['MatchDate'])

# Line chart of total goals over time
plt.figure(figsize=(12, 5))
sns.lineplot(data=df, x='MatchDate', y='Total_Goals')
plt.title('Total Goals Scored Over Time')
plt.xlabel('Match Date')
plt.ylabel('Total Goals')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot total goals per match over time

# %% [markdown]
# ---

# %% [markdown]
# # Final Data Check

# %%
df.head()
# Out:
#     Season  MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01 2000-08-19  Charlton       Man City                  4
# 1  2000/01 2000-08-19   Chelsea       West Ham                  4
# 2  2000/01 2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01 2000-08-19     Derby    Southampton                  2
# 4  2000/01 2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  AwayCorners  HomeFouls  AwayFouls  HomeYellowCards  \
# ...

# %% [markdown]
# Check the data with 1000 rows

# %%
df.head(1000)
# Out:
#       Season  MatchDate   HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0    2000/01 2000-08-19   Charlton       Man City                  4
# 1    2000/01 2000-08-19    Chelsea       West Ham                  4
# 2    2000/01 2000-08-19   Coventry  Middlesbrough                  1
# 3    2000/01 2000-08-19      Derby    Southampton                  2
# 4    2000/01 2000-08-19      Leeds        Everton                  2
# ..       ...        ...        ...            ...                ...
# 995  2002/03 2003-01-19    Arsenal       West Ham                  3
# 996  2002/03 2003-01-19     Fulham  Middlesbrough                  1
# 997  2002/03 2003-01-22   Charlton       West Ham                  4
# 998  2002/03 2003-01-22  Newcastle         Bolton                  1
# 999  2002/03 2003-01-28     Bolton        Everton                  1
#
#      FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# ...

# %% [markdown]
# This makes sure to check that the new columns are all visible in the table:
#
# - Result
# - Goal_Diff
# - Total_Goals

# %% [markdown]
# ## Data Preparation Summary
#
# - Missing values handled
# - Date column converted for time-based analysis
# - Created new columns:
#   - `Result`: Home Win / Away Win / Draw
#   - `Goal_Diff`: Goal difference (home - away)
#   - `Total_Goals`: Combined goals per match

# %% [markdown]
# # Now Saving the cleaned data set to a new csv file

# %%
# Save cleaned data to CSV
df.to_csv('data/epl_cleaned.csv', index=False)

# %% [markdown]
# ## Save Cleaned Data
#
# Saved the cleaned and processed data to `epl_cleaned.csv` for use in later analysis and our Streamlit dashboard
